# %%
from tensorflow.keras import models, layers, activations, initializers

model = models.Sequential([
    layers.Input(shape=(28,28,3)), # 28x28x1
    layers.Conv2D(10, kernel_size=(3,3), strides=(1,1), padding='same'), # 10 @ 28x28
    layers.Flatten(), # 7840
    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()), # 64
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal()) # 24
])

# %%
from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

# %%
from tensorflow.keras import utils

path = './Data'
batch_size = 64

train = utils.image_dataset_from_directory(
    directory=path + '/Data/Train',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)

test = utils.image_dataset_from_directory(
    directory=path + '/Data/Test',
    shuffle = True,
    seed = 1,
    image_size = (28,28),
    batch_size = batch_size
)
# Out:
# Found 27455 files belonging to 24 classes.
# Found 7172 files belonging to 24 classes.

# %%
from tensorflow.keras import callbacks

patience = 5
epochs = 100

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = True
        )
    ]
)
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 10.3069 - sparse_categorical_accuracy: 0.0432 - val_loss: 3.1957 - val_sparse_categorical_accuracy: 0.0290
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 3.1725 - sparse_categorical_accuracy: 0.0462 - val_loss: 3.1915 - val_sparse_categorical_accuracy: 0.0229
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3.1698 - sparse_categorical_accuracy: 0.0470 - val_loss: 3.1957 - val_sparse_categorical_accuracy: 0.0229
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3.1696 - sparse_categorical_accuracy: 0.0464 - val_loss: 3.2223 - val_sparse_categorical_accuracy: 0.0231
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 3.1511 - sparse_categorical_accuracy: 0.0543 - val_loss: 3.2151 - val_sparse_categorical_accuracy: 0.0209
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3.1615 - sparse_categorical_accuracy: 0.0520 - val_loss: 3.2008 - val_sparse_categorical_accuracy: 0.0201
# Epoch 7/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3.1755 - sparse_categorical_accuracy: 0.0476 - val_loss: 3.2010 - val_sparse_categorical_accuracy: 0.0201
# Epoch 7: early stopping

# %%
from tensorflow.keras import models, layers, activations, initializers

model = models.Sequential([
    layers.Input(shape=(28,28,3)), 
    
    layers.Resizing(28,28),
    layers.Rescaling(1./255),
    layers.RandomRotation((-0.2, 0.2)),

    layers.Conv2D(10, kernel_size=(3,3), strides=(1,1), padding='same'),
    layers.MaxPooling2D((2,2)),
    
    layers.Flatten(),

    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
    layers.Dropout(0.2),
    layers.Dense(64, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
    layers.Dense(24, activation=activations.softmax, kernel_initializer=initializers.RandomNormal())
])

from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

from tensorflow.keras import callbacks

patience = 5
epochs = 100
model_path = "./model.keras"

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        ),
        callbacks .ModelCheckpoint(
            filepath = model_path,
            save_weights_only = False,
            monitor = 'loss',
            mode = 'min',
            save_best_only = True
        )
    ]
)
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.8292 - sparse_categorical_accuracy: 0.1154 - val_loss: 2.3431 - val_sparse_categorical_accuracy: 0.2204
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 2.4160 - sparse_categorical_accuracy: 0.2110 - val_loss: 2.0788 - val_sparse_categorical_accuracy: 0.3263
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 2.1575 - sparse_categorical_accuracy: 0.2813 - val_loss: 1.7801 - val_sparse_categorical_accuracy: 0.3799
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1.7488 - sparse_categorical_accuracy: 0.4094 - val_loss: 1.4336 - val_sparse_categorical_accuracy: 0.4923
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 1.3946 - sparse_categorical_accuracy: 0.5248 - val_loss: 1.1893 - val_sparse_categorical_accuracy: 0.5775
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1.1485 - sparse_categorical_accuracy: 0.6013 - val_loss: 0.9884 - val_sparse_categorical_accuracy: 0.6385
# Epoch 7/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.9817 - sparse_categorical_accuracy: 0.6587 - val_loss: 0.8959 - val_sparse_categorical_accuracy: 0.6857
# Epoch 8/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.8775 - sparse_categorical_accuracy: 0.6984 - val_loss: 0.8309 - val_sparse_categorical_accuracy: 0.7100
# Epoch 9/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.7973 - sparse_categorical_accuracy: 0.7250 - val_loss: 0.8247 - val_sparse_categorical_accuracy: 0.7423
# Epoch 10/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.7209 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.8025 - val_sparse_categorical_accuracy: 0.7245
# Epoch 11/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.6604 - sparse_categorical_accuracy: 0.7713 - val_loss: 0.7379 - val_sparse_categorical_accuracy: 0.7658
# Epoch 12/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.6083 - sparse_categorical_accuracy: 0.7893 - val_loss: 0.7250 - val_sparse_categorical_accuracy: 0.7543
# Epoch 13/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.5737 - sparse_categorical_accuracy: 0.8025 - val_loss: 0.6822 - val_sparse_categorical_accuracy: 0.7697
# Epoch 14/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.5366 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.7215 - val_sparse_categorical_accuracy: 0.7712
# Epoch 15/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.5057 - sparse_categorical_accuracy: 0.8249 - val_loss: 0.6900 - val_sparse_categorical_accuracy: 0.7751
# Epoch 16/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.4748 - sparse_categorical_accuracy: 0.8366 - val_loss: 0.6432 - val_sparse_categorical_accuracy: 0.7833
# Epoch 17/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.4562 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.6252 - val_sparse_categorical_accuracy: 0.8009
# Epoch 18/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.4300 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.6806 - val_sparse_categorical_accuracy: 0.7910
# Epoch 19/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.4293 - sparse_categorical_accuracy: 0.8526 - val_loss: 0.6551 - val_sparse_categorical_accuracy: 0.8062
# Epoch 20/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.4027 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.6192 - val_sparse_categorical_accuracy: 0.8161
# Epoch 21/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.3936 - sparse_categorical_accuracy: 0.8661 - val_loss: 0.6377 - val_sparse_categorical_accuracy: 0.8118
# Epoch 22/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.3811 - sparse_categorical_accuracy: 0.8683 - val_loss: 0.6110 - val_sparse_categorical_accuracy: 0.8144
# Epoch 23/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.3560 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.6202 - val_sparse_categorical_accuracy: 0.8238
# Epoch 24/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.3502 - sparse_categorical_accuracy: 0.8803 - val_loss: 0.6612 - val_sparse_categorical_accuracy: 0.8090
# Epoch 25/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.3326 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.6095 - val_sparse_categorical_accuracy: 0.8330
# Epoch 26/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.3356 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.5799 - val_sparse_categorical_accuracy: 0.8355
# Epoch 27/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.3103 - sparse_categorical_accuracy: 0.8923 - val_loss: 0.6082 - val_sparse_categorical_accuracy: 0.8275
# Epoch 28/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.3097 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.6808 - val_sparse_categorical_accuracy: 0.8151
# Epoch 29/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.3021 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.6404 - val_sparse_categorical_accuracy: 0.8338
# Epoch 30/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.2887 - sparse_categorical_accuracy: 0.9016 - val_loss: 0.6648 - val_sparse_categorical_accuracy: 0.8261
# Epoch 31/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9002 - val_loss: 0.5950 - val_sparse_categorical_accuracy: 0.8367
# Epoch 31: early stopping
